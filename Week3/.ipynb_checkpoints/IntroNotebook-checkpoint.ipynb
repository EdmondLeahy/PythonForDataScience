# %% [markdown]
# # Welcome to Week3
# ## This is how to title
#
# Bullet time:
# * One
# * Two
# * three

# %% [markdown]
# $\int_0^\infty x^{-\alpha}$

# %%
#%matplotlib inline
from matplotlib.pyplot import plot

plot([0,10,0,1])

# %% [markdown]
# This is a graph that explains literally nothing
